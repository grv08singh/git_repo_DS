# %%
import os
from pathlib import Path

# %%
os.getcwd()
# Out:
# 'F:\\Grv\\Grv\\06 Personal\\GIT\\01_masterRepo\\01_My_Learnings\\05_NSO_work'

# %%
def main_method():
    print(f"Main Method 1: {os.getcwd()}")
    os.chdir('.//software')
    print(f"Main Method 2: {os.getcwd()}")
    sub_method()
    print(f"Main Method 3: {os.getcwd()}")
    folder_path = Path('./01_software')
    print(f"Folder Path: {folder_path}")
    print(f"Main Method 4: {os.getcwd()}")

# %%
def sub_method():
    print(f"Sub Method 1: {os.getcwd()}")
    os.chdir('..')
    print(f"Sub Method 2: {os.getcwd()}")

# %%
if __name__ == "__main__":
    main_method()
# Out:
# Main Method 1: F:\Grv\Grv\06 Personal\GIT\01_masterRepo\01_My_Learnings\05_NSO_work
# Main Method 2: F:\Grv\Grv\06 Personal\GIT\01_masterRepo\01_My_Learnings\05_NSO_work\software
# Sub Method 1: F:\Grv\Grv\06 Personal\GIT\01_masterRepo\01_My_Learnings\05_NSO_work\software
# Sub Method 2: F:\Grv\Grv\06 Personal\GIT\01_masterRepo\01_My_Learnings\05_NSO_work
# Main Method 3: F:\Grv\Grv\06 Personal\GIT\01_masterRepo\01_My_Learnings\05_NSO_work
# Folder Path: 01_software
# Main Method 4: F:\Grv\Grv\06 Personal\GIT\01_masterRepo\01_My_Learnings\05_NSO_work
