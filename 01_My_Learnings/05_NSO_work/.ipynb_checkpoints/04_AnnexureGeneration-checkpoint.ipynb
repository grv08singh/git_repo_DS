# %%
from pathlib import Path
from xlsxwriter import Workbook
import numpy as np
import pandas as pd
import pyodbc
import sys
import os
import time
from datetime import date
import re
import warnings as wr
wr.filterwarnings('ignore')

# %%
seasons_as10 = {1:'Kharif', 2:'Phase-I', 3:'Phase-II', 4:'Phase-III', 5:'Summer'}
seasons_as20 = {1:'Kharif', 2:'E.Kharif', 3:'L.Kharif', 4:'Rabi', 5:'Summer'}

# %%
def clean_rc123(details):
    
    #get data from the table - RC1
    st_cd = details[st_cd]
    state_cd = details[state_cd]
    year = details[year]
    planning = details[planning]
    novcod = details[novcod]
    season_codes = details[season_codes]
    ddg = details[ddg]
    ddtrs = details[ddtrs]



    
    #set database file path
    folder_path = Path('./software')
    for file_path in folder_path.iterdir():
        if file_path.is_file():
            if season_nm.lower() in file_path.name.lower():
                accdb_path = "./" + "/".join(str(file_path).split("\\"))
    
    #create connection with mdb database
    conn_str = (
        r'DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};'
        f'DBQ={accdb_path};'
    )
    conn = pyodbc.connect(conn_str)
    
    cols1 = ['RC', 'ST', 'YR', 'SESON', 'NOVP', 'NOVCOD', 'STAT', 'DIST', 'STRA',
           'VILL', 'EPC', 'NOVPC', 'NOVTRS', 'CADC', 'TLC', 'MAC', 'MUC', 'DDG',
           'SGC', 'GCC', 'LFOG', 'ROG', 'DDTRS', 'TRSSC', 'TRSSF', 'DCKC', 'HSSN',
           'GEOA', 'TCROPA', 'TNSSN', 'TGEOASN', 'RC61', 'RC62', 'RC63', 'REJ']
    
    sql_query1 = 'SELECT * FROM "Copy Of RC1"'
    df1 = pd.read_sql(sql_query1, conn)[cols1]
    
    df1 = (df1
        .drop_duplicates()
        .apply(pd.to_numeric, errors='coerce')
        .query("STAT == @state_cd and SESON == @season_cd")
        .assign(
            REJ = lambda x : np.where(x['REJ']==1, 1, 0)
            ,NOVPC1 = lambda x : x['NOVPC'].fillna(1)
            ,NOVPC = lambda x : np.where(x['NOVPC1']==0, 1, x['NOVPC1'])
            ,NOVTRS1 = lambda x : x['NOVTRS'].fillna(1)
            ,NOVTRS = lambda x : np.where(x['NOVTRS1']==0, 1, x['NOVTRS1'])
            ,CADC = lambda x : np.where(np.isin(x['CADC'], [1,2,3,4]), x['CADC'], 9)
            ,TLC = lambda x : np.where(x['CADC']==3, 0, np.where(np.isin(x['CADC'], [4,9]), 8, x['TLC']))
            ,MAC = lambda x : np.where(x['MAC']==1, 1, 0)
            ,MUC = lambda x : np.where(x['MAC']==1, x['MUC'], None)
            ,TRSSC = lambda x : np.where(x['TRSSC']==3, 8, x['TRSSC'])
            ,NOVP = planning
            ,DDG = ddg
            ,DDTRS = ddtrs
            ,TCROPA = lambda x : x['TCROPA'].fillna(0)
            ,GEOA = lambda x : x['GEOA'].fillna(0)
            ,YR = year+1
            ,NOVCOD = novcod
            ,LFOG = lambda x : np.where(~np.isin(x['LFOG'], [0,1]), None, x['LFOG'])
            ,ROG = lambda x : np.where(~np.isin(x['ROG'], [0,1]), None, x['ROG'])
            ,TRSSF = lambda x : np.where(x['TRSSF'].isna(), None, x['TRSSF'])
        )
        .drop(columns = ['NOVPC1','NOVTRS1'])
    )
    
    non_rej_rc1 = df1[df1['REJ']!=1]
    rej_rc1 = df1[df1['REJ']==1].assign(
    	EPC = None
    	,NOVPC = None
    	,NOVTRS = None
    	,CADC = None
    	,TLC = None
    	,MAC = None
    	,MUC = None
    	,DDG = None
    	,SGC = None
    	,GCC = None
    	,LFOG = None
    	,ROG = None
    	,DDTRS = None
    	,TRSSC = None
    	,TRSSF = None
    	,DCKC = None
    	,HSSN = None
    	,GEOA = None
    	,TCROPA = None
    	,TNSSN = None
    	,TGEOASN = None
    	,RC61 = None
    	,RC62 = None
    	,RC63 = None
    )
    rc1 = pd.concat([non_rej_rc1, rej_rc1], ignore_index=True)
    
    if rc1['HSSN'].isna().sum() > 0:
        print('='*50)
        print('In RC1, HSSN is Blank. Please Correct...')
        print('='*50)
    if rc1[rc1['HSSN'] == 0].shape[0] > 0:
        print('='*50)
        print('In RC1, HSSN is Zero. Please Correct...')
        print('='*50)
    if rc1['GEOA'].isna().sum() > 0:
        print('='*50)
        print('In RC1, GEOA is Blank. Please Correct...')
        print('='*50)
    if rc1[rc1['GEOA'] == 0].shape[0] > 0:
        print('='*50)
        print('In RC1, GEOA is Zero. Please Correct...')
        print('='*50)
    
    
    rc1.to_excel(excel_writer='RC1237_clean.xlsx', sheet_name='RC1', index=False, engine='openpyxl')
    
    
    
    
    
    
    
    #get data from the table - RC2
    cols2 = ['RC', 'ST', 'YR', 'SESON', 'STAT', 'DIST', 'STRA', 'VILL', 'EPC', 
             'HSSN', 'TNSSN', 'CROP', 'VARC', 'ARSU', 'ARSI', 'ARPU', 'ARPI']
    
    sql_query2 = 'SELECT * FROM "Copy Of RC2"'
    df2 = pd.read_sql(sql_query2, conn)[cols2]
    df2 = (df2
        .drop_duplicates()
        .apply(pd.to_numeric, errors='coerce')
        .query("STAT == @state_cd and SESON == @season_cd")
        .assign(
            YR = year+1
            ,VARC = lambda x : np.where(x['CROP']==0, 0, x['VARC'])
            ,CROP = lambda x : np.where(x['VARC']==0, 0, x['CROP'])
        )
    )
    rc2 = df2.copy()
    
    with pd.ExcelWriter('RC1237_clean.xlsx', mode='a', engine='openpyxl') as w2:
        rc2.to_excel(w2, sheet_name='RC2', index=False)
    
    
    
    
    
    
    
    #get data from the table - RC3
    cols3 = ['RC', 'ST', 'YR', 'SESON', 'STAT', 'DIST', 'STRA',
             'VILL', 'SN', 'CROP', 'VARC', 'IRRC', 'ERC']
    
    sql_query3 = 'SELECT * FROM "Copy Of RC3"'
    df3 = pd.read_sql(sql_query3, conn)[cols3]
    df3 = (df3
        .apply(pd.to_numeric, errors='coerce')
        .query("STAT == @state_cd and SESON == @season_cd")
        .assign(
            YR = year+1
            ,VARC = lambda x : np.where(x['CROP']==0, 0, x['VARC'])
            ,CROP = lambda x : np.where(x['VARC']==0, 0, x['CROP'])
        )
    )
    
    #creating schedule unique id in RC1
    rc1_bkp = rc1.copy()
    rc1['unique_id'] = rc1['STAT'].astype(str) + "_" + rc1['SESON'].astype(str) + "_" + rc1['ST'].astype(str) + "_" + rc1['STRA'].astype(str) + "_" + rc1['VILL'].astype(str)+ "_" + rc1['DIST'].astype(str)
    
    
    #creating schedule unique id in df3
    df3['unique_id'] = df3['STAT'].astype(str) + "_" + df3['SESON'].astype(str) + "_" + df3['ST'].astype(str) + "_" + df3['STRA'].astype(str) + "_" + df3['VILL'].astype(str)+ "_" + df3['DIST'].astype(str)
    
    #Left Join on df3 with rc1_epc1
    rc1_epc = rc1[['unique_id','EPC']]
    rc3 = pd.merge(df3, rc1_epc, how='left', left_on='unique_id', right_on='unique_id')
    rc3 = rc3[rc3['EPC'] == 1].drop(columns=['unique_id','EPC'])
    
    with pd.ExcelWriter('RC1237_clean.xlsx', mode='a', engine='openpyxl') as w3:
        rc3.to_excel(w3, sheet_name='RC3', index=False)
    
    
    
    
    
    conn.close()
    return rc1_bkp, rc2, rc3

# %%
def clean_rc7():


    #data to be provided
    year = 2024
    state_cd = 33
    season_cd = 1
    crop_plan_c = {
        91 : 40,
        3 : 40,
        5 : 40,
        6 : 40,
        15 : 40,
        33 : 40,
        11 : 40,
        12 : 40,
        92 : 60,
        14 : 40
    }
    
    crop_plan_s = {
        91 : 40,
        3 : 40,
        5 : 40,
        6 : 40,
        15 : 40,
        33 : 40,
        11 : 40,
        12 : 40,
        92 : 60,
        14 : 40
    }
    
    crop_ccf = {
        91 : 0.9352* 0.6667* 0.4,
        3 : 0.6091* 1* 0.4,
        5 : 0.718* 1* 0.4,
        6 : 0.7863* 1* 0.4,
        15 : 0.7378* 1* 0.4,
        33 : 1* 1* 0.2,
        11 : 1* 1* 0.2,
        12 : 1* 0.3295* 0.2,
        92 : 0.9324* 0.6667* 0.4,
        14 : 1* 1* 0.4
    }
    
    
    d_ST = {1 : "Central", 2 : "State"}


    
    #set database file path
    folder_path = Path('./software')
    for file_path in folder_path.iterdir():
        if file_path.is_file():
            if 'NSSAS' in file_path.name:
                mdb_path = "./" + "/".join(str(file_path).split("\\"))
    
    #create connection with mdb database
    conn_str = (
        r'DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};'
        f'DBQ={mdb_path};'
    )
    conn = pyodbc.connect(conn_str)
    
    #get data from the table - Sch20RC7
    cols7 = ['RC', 'ST', 'YR', 'SESON', 'CROP', 'NEXP', 'NEXNR', 'CONFAC', 
             'STAT', 'DIST', 'VILL', 'RSV', 'EXPNO', 'STAGIN', 'REXML', 
             'CCE', 'CFC', 'RCSSN', 'E1', 'E2', 'E9', 'E10', 'E11', 'E12', 
             'ADH', 'QTYG', 'QTYP', 'E13', 'EQST', 'EQSB', 'EQSW', 'EQSP', 
             'E14', 'STYPE', 'E3', 'SVARC', 'SEEDR', 'E4', 'IRR', 'E5', 
             'IRRP', 'NIRR', 'FERTC', 'E6', 'QTN', 'CODN', 'QTP', 'CODP', 
             'QTK', 'CODK', 'MANUR', 'E7', 'PEST', 'E8', 'E15', 'REJ', 
             'CROPER', 'CROPCON', 'AFFECT']
    
    sql_query7 = 'SELECT * FROM "Sch20RC7"'
    rc7 = pd.read_sql(sql_query7, conn)[cols7]
    rc7 = (rc7
        .drop_duplicates()
        .apply(pd.to_numeric, errors="coerce")
        .query("STAT == @state_cd and SESON == @season_cd")
        .assign(
            #adjusting cotton crop code
            YR = year+1
            ,CROP = lambda x : x['CROP'].replace({55: 12, 57: 56})
            ,REJ = lambda x : x['REJ'].apply(lambda y : 1 if y==1 else 0)
            ,RSV = lambda x: x['RSV'].where(x["RSV"].isin([0, 1, 2, 3, 9]), 0)
            ,REXML = lambda x: x["REXML"].where(
                        ~(x["STAGIN"].isin([2, 3]) & ~x["REXML"].isin([1, 2, 3, 4, 9])),
                        9
            )
            ,CFC = lambda x: x["CFC"].where(
                        ~(x["STAGIN"].isin([1, 2]) & ~x["CFC"].isin([1, 2, 3, 4])),
                        4
            )
            ,RCSSN = lambda x: x["RCSSN"].where(
                ~(x["STAGIN"].isin([1, 2]) & ~x["RCSSN"].isin([0, 1, 2, 3, 9])),
                0
            )
            ,EQST = lambda x: x["EQST"].where(
                ~(x["STAGIN"].isin([1, 2]) & x["EQST"].isna()),
                9
            )
            ,EQSB = lambda x: x["EQSB"].where(
                ~(x["STAGIN"].isin([1, 2]) & x["EQSB"].isna()),
                9
            )
            ,EQSW = lambda x: x["EQSW"].where(
                ~(x["STAGIN"].isin([1, 2]) & x["EQSW"].isna()),
                9
            )
            ,EQSP = lambda x: x["EQSP"].where(
                ~(x["STAGIN"].isin([1, 2]) & x["EQSP"].isna()),
                9
            )
            ,QTYG = lambda x: (
                x["QTYG"]
                .where(x["STAGIN"] != 2, None)
                .where(~(x["STAGIN"].eq(1) & x["CROPCON"].eq(4)), 0)
            )
            ,QTYP = lambda x: (
                x["QTYP"]
                .where(x["STAGIN"] != 2, None)
                .where(~(x["STAGIN"].eq(1) & x["CROPCON"].eq(4)), 0)
            )
            ,E13 = lambda x: x["E13"].where(x["STAGIN"] != 2, None)
            ,AFFECT = lambda x: x['AFFECT'].where(~((x['STAGIN'].isin([1,2])) & (x['CROPCON'].isin([1,2]))), 0)
            ,IRR = lambda x : np.where(x['NIRR']>0, 1, 0)
            ,CODN = lambda x : x['CODN'].where(~(x['QTN']>0), 1)
            ,CODP = lambda x : x['CODP'].where(~(x['QTP']>0), 1)
            ,CODK = lambda x : x['CODK'].where(~(x['QTK']>0), 1)
            ,FERTC = lambda x : np.where(((x['QTN']>0) | (x['QTP']>0) | (x['QTK']>0) | (x['CODN']==9) | (x['CODP']==9) | (x['CODK']==9)), 1, 0)
            
        )
    )
    
    rc7.loc[((rc7['STAGIN'].isin([1,2])) & (rc7['CODN']==8) & (rc7['CODP']==8) & 
        (rc7['CODK']==8) & ((rc7['QTN']==0) | rc7['QTN'].isna()) & 
        ((rc7['QTP']==0) | rc7['QTP'].isna()) & ((rc7['QTK']==0) | rc7['QTK'].isna())), 'FERTC'] = 0
    
    rc7.loc[((rc7['STAGIN'].isin([1,2])) & (rc7['CODN']==8) & (rc7['CODP']==8) & 
        (rc7['CODK']==8) & ((rc7['QTN']==0) | rc7['QTN'].isna()) & 
        ((rc7['QTP']==0) | rc7['QTP'].isna()) & ((rc7['QTK']==0) | rc7['QTK'].isna())), 'QTN'] = np.nan
    
    rc7.loc[((rc7['STAGIN'].isin([1,2])) & (rc7['CODN']==8) & (rc7['CODP']==8) & 
        (rc7['CODK']==8) & ((rc7['QTN']==0) | rc7['QTN'].isna()) & 
        ((rc7['QTP']==0) | rc7['QTP'].isna()) & ((rc7['QTK']==0) | rc7['QTK'].isna())), 'QTP'] = np.nan
    
    rc7.loc[((rc7['STAGIN'].isin([1,2])) & (rc7['CODN']==8) & (rc7['CODP']==8) & 
        (rc7['CODK']==8) & ((rc7['QTN']==0) | rc7['QTN'].isna()) & 
        ((rc7['QTP']==0) | rc7['QTP'].isna()) & ((rc7['QTK']==0) | rc7['QTK'].isna())), 'QTK'] = np.nan
    
    rc7.loc[~((rc7['CODN'].isin([1,8,9])) | (rc7['CODN'].isna())), 'CODN'] = np.nan
    rc7.loc[~((rc7['CODP'].isin([1,8,9])) | (rc7['CODP'].isna())), 'CODP'] = np.nan
    rc7.loc[~((rc7['CODK'].isin([1,8,9])) | (rc7['CODK'].isna())), 'CODK'] = np.nan
    
    rc7.loc[((rc7['STAGIN'].isin([1,2])) & (rc7['CODN'].isna()) & (rc7['CODP'].isna()) & (rc7['CODK'].isna())), 'FERTC'] = 0
    rc7.loc[((rc7['STAGIN'].isin([1,2])) & (rc7['CODN'].isna()) & (rc7['CODP'].isna()) & (rc7['CODK'].isna())), 'QTN'] = np.nan
    rc7.loc[((rc7['STAGIN'].isin([1,2])) & (rc7['CODN'].isna()) & (rc7['CODP'].isna()) & (rc7['CODK'].isna())), 'QTP'] = np.nan
    rc7.loc[((rc7['STAGIN'].isin([1,2])) & (rc7['CODN'].isna()) & (rc7['CODP'].isna()) & (rc7['CODK'].isna())), 'QTK'] = np.nan
    
    rc7.loc[(rc7['FERTC']==0), 'QTN'] = np.nan
    rc7.loc[(rc7['FERTC']==0), 'QTP'] = np.nan
    rc7.loc[(rc7['FERTC']==0), 'QTK'] = np.nan
    rc7.loc[(rc7['FERTC']==0), 'CODN'] = 8
    rc7.loc[(rc7['FERTC']==0), 'CODP'] = 8
    rc7.loc[(rc7['FERTC']==0), 'CODK'] = 8
    
    lost_cols = ['CCE', 'CFC', 'RCSSN', 'E1', 'E2', 'E9', 'E10', 'E11', 'E12', 
                 'ADH', 'QTYG', 'QTYP', 'E13', 'EQST', 'EQSB', 'EQSW', 'EQSP',
                 'E14', 'STYPE', 'E3', 'SVARC', 'SEEDR', 'E4', 'IRR', 'E5',
                 'IRRP', 'NIRR', 'FERTC', 'E6', 'QTN', 'CODN', 'QTP', 'CODP',
                 'QTK', 'CODK', 'MANUR', 'E7', 'PEST', 'E8', 'E15','CROPER', 
                 'CROPCON', 'AFFECT']
    
    for col in lost_cols:
        rc7.loc[rc7['STAGIN']==3, col] = np.nan
    
    for crop,plan in crop_plan_c.items():
        rc7.loc[((rc7['ST']==1) & (rc7['CROP']==crop)), 'NEXP'] = plan
        received = rc7[(rc7['ST']==1) & (rc7['CROP']==crop)].shape[0]
        rc7.loc[((rc7['ST']==1) & (rc7['CROP']==crop)), 'NEXR'] = received
    
    for crop,plan in crop_plan_c.items():
        rc7.loc[((rc7['ST']==2) & (rc7['CROP']==crop)), 'NEXP'] = plan
        received = rc7[(rc7['ST']==1) & (rc7['CROP']==crop)].shape[0]
        rc7.loc[((rc7['ST']==2) & (rc7['CROP']==crop)), 'NEXR'] = received
    
    for crop, ccf in crop_ccf.items():
        if ccf<1:
            ccf = np.floor(ccf*10000)
        rc7.loc[(rc7['CROP']==crop), 'CONFAC'] = ccf
        
    rc7['NEXNR'] = rc7['NEXP'].sub(rc7['NEXR'], fill_value=0)
    
    with pd.ExcelWriter('RC1237_clean.xlsx', mode='a', engine='openpyxl') as w7:
        rc7.to_excel(w7, sheet_name='RC7', index=False)
    
    conn.close()
    return rc7

# %%
if __name__ == "__main__":
    #read & clean RCs
    state_code = 33
    year_int = 2024                   #2024 for A.Y. 2024-25
    season_codes = [2,3]              #1-Kharif, 4-Rabi
    st_codes = [1,2]                  #1-Central, 2-State
    season_novp = {
        1 : [0,0],                     ##season_1 planning [cen, state]
        2 : [260, 260],                ##season_2 planning [cen, state]
        3 : [260, 260],                ##season_3 planning [cen, state]
        4 : [260, 260],                ##season_4 planning [cen, state]
        5 : [0,0]                      ##season_5 planning [cen, state]
    }
    rc1_novcod = {
        1 : [0,0],                     ##season_1 NOVCOD [cen, state]
        2 : [260, 260],                ##season_2 NOVCOD [cen, state]
        3 : [260, 260],                ##season_3 NOVCOD [cen, state]
        4 : [260, 260],                ##season_4 NOVCOD [cen, state]
        5 : [0,0]                      ##season_5 NOVCOD [cen, state]
    }

    for season_code in season_codes:
        for st_code in st_codes:
            details = {
                st_cd : st_code,
                state_cd : state_code,
                year : year_int,
                planning : season_novp[season_code][st_code-1],
                novcod : rc1_novcod[season_code][st_code-1],
                season_codes : [1,2,3],
                ddg : 2510,
                ddtrs : 2810
            }
            rc1, rc2, rc3 = clean_rc123(details)
            rc7 = clean_rc7()

    #Generate Annexure Data
    pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 20
#       5 rc1_novp = {
#       6     1 : [0,0],                     ##season_1 planning [cen, state]
#       7     2 : [260, 260],                ##season_2 planning [cen, state]
#    (...)
#      10     5 : [0,0]                      ##season_5 planning [cen, state]
#      11 }
#      12 rc1_novcod = {
#      13     1 : [0,0],                     ##season_1 NOVCOD [cen, state]
#      14     2 : [260, 260],                ##season_2 NOVCOD [cen, state]
#    (...)
#      17     5 : [0,0]                      ##season_5 NOVCOD [cen, state]
#      18 }
# ---> 20 rc1, rc2, rc3 = clean_rc123()
#      21 rc7 = clean_rc7()
#      23 #Generate Annexure Data
#
# Cell In[3], line 40, in clean_rc123()
#      34 sql_query1 = 'SELECT * FROM "Copy Of RC1"'
#      35 df1 = pd.read_sql(sql_query1, conn)[cols1]
#      37 df1 = (df1
#      38     .drop_duplicates()
#      39     .apply(pd.to_numeric, errors='coerce')
# ---> 40     .query("STAT == @state_cd and SESON in @season_cd")
#      41     .assign(
#      42         REJ = lambda x : np.where(x['REJ']==1, 1, 0)
#      43         ,NOVPC1 = lambda x : x['NOVPC'].fillna(1)
#      44         ,NOVPC = lambda x : np.where(x['NOVPC1']==0, 1, x['NOVPC1'])
#      45         ,NOVTRS1 = lambda x : x['NOVTRS'].fillna(1)
#      46         ,NOVTRS = lambda x : np.where(x['NOVTRS1']==0, 1, x['NOVTRS1'])
#      47         ,CADC = lambda x : np.where(np.isin(x['CADC'], [1,2,3,4]), x['CADC'], 9)
#      48         ,TLC = lambda x : np.where(x['CADC']==3, 0, np.where(np.isin(x['CADC'], [4,9]), 8, x['TLC']))
#      49         ,MAC = lambda x : np.where(x['MAC']==1, 1, 0)
#      50         ,MUC = lambda x : np.where(x['MAC']==1, x['MUC'], None)
#      51         ,TRSSC = lambda x : np.where(x['TRSSC']==3, 8, x['TRSSC'])
#      52         ,NOVP = planning
#      53         ,DDG = ddg
#      54         ,DDTRS = ddtrs
#      55         ,TCROPA = lambda x : x['TCROPA'].fillna(0)
#      56         ,GEOA = lambda x : x['GEOA'].fillna(0)
#      57         ,YR = year+1
#      58         ,NOVCOD = b4_cod
#      59         ,LFOG = lambda x : np.where(~np.isin(x['LFOG'], [0,1]), None, x['LFOG'])
#      60         ,ROG = lambda x : np.where(~np.isin(x['ROG'], [0,1]), None, x['ROG'])
#      61         ,TRSSF = lambda x : np.where(x['TRSSF'].isna(), None, x['TRSSF'])
#      62     )
#      63     .drop(columns = ['NOVPC1','NOVTRS1'])
#      64 )
#      66 non_rej_rc1 = df1[df1['REJ']!=1]
#      67 rej_rc1 = df1[df1['REJ']==1].assign(
#      68 	EPC = None
#      69 	,NOVPC = None
#    (...)
#      91 	,RC63 = None
#      92 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4823, in DataFrame.query(self, expr, inplace, **kwargs)
#    4821 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822 kwargs["target"] = None
# -> 4823 res = self.eval(expr, **kwargs)
#    4825 try:
#    4826     result = self.loc[res]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4949, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4946     kwargs["target"] = self
#    4947 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4949 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:805, in Expr.__init__(self, expr, engine, parser, env, level)
#     803 self.parser = parser
#     804 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 805 self.terms = self.parse()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:824, in Expr.parse(self)
#     820 def parse(self):
#     821     """
#     822     Parse an expression.
#     823     """
# --> 824     return self._visitor.visit(self.expr)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:417, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     415     raise SyntaxError("only a single expression is allowed")
#     416 expr = node.body[0]
# --> 417 return self.visit(expr, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:420, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     419 def visit_Expr(self, node, **kwargs):
# --> 420     return self.visit(node.value, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:742, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     739     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     741 operands = node.values
# --> 742 return reduce(visitor, operands)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:736, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     734 def visitor(x, y):
#     735     lhs = self._try_visit_binop(x)
# --> 736     rhs = self._try_visit_binop(y)
#     738     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#     739     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:731, in BaseExprVisitor._try_visit_binop(self, bop)
#     729 if isinstance(bop, (Op, Term)):
#     730     return bop
# --> 731 return self.visit(bop)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:715, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     713     op = self.translate_In(ops[0])
#     714     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 715     return self.visit(binop)
#     717 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     718 left = node.left
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:533, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     531 op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     532 left, right = self._maybe_downcast_constants(left, right)
# --> 533 return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:519, in BaseExprVisitor._maybe_evaluate_binop(self, op, op_class, lhs, rhs, eval_in_python, maybe_eval_in_python)
#     515     return self._maybe_eval(res, self.binary_ops)
#     517 if res.op in eval_in_python:
#     518     # "in"/"not in" ops are always evaluated in python
# --> 519     return self._maybe_eval(res, eval_in_python)
#     520 elif self.engine != "pytables":
#     521     if (
#     522         getattr(lhs, "return_type", None) == object
#     523         or getattr(rhs, "return_type", None) == object
#     524     ):
#     525         # evaluate "==" and "!=" in python if either of our operands
#     526         # has an object return type
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:487, in BaseExprVisitor._maybe_eval(self, binop, eval_in_python)
#     480 def _maybe_eval(self, binop, eval_in_python):
#     481     # eval `in` and `not in` (for now) in "partial" python space
#     482     # things that can be evaluated in "eval" space will be turned into
#    (...)
#     485     # in that case a + 2 * b will be evaluated using numexpr, and the "in"
#     486     # call will be evaluated using isin (in python space)
# --> 487     return binop.evaluate(
#     488         self.env, self.engine, self.parser, self.term_type, eval_in_python
#     489     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:427, in BinOp.evaluate(self, env, engine, parser, term_type, eval_in_python)
#     425 # base cases
#     426 if self.op in eval_in_python:
# --> 427     res = self.func(left.value, right.value)
#     428 else:
#     429     from pandas.core.computation.eval import eval
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:268, in _in(x, y)
#     263 """
#     264 Compute the vectorized membership of ``x in y`` if possible, otherwise
#     265 use Python.
#     266 """
#     267 try:
# --> 268     return x.isin(y)
#     269 except AttributeError:
#     270     if is_list_like(x):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:5559, in Series.isin(self, values)
#    5486 def isin(self, values) -> Series:
#    5487     """
#    5488     Whether elements in Series are contained in `values`.
#    5489
#    (...)
#    5557     dtype: bool
#    5558     """
# -> 5559     result = algorithms.isin(self._values, values)
#    5560     return self._constructor(result, index=self.index, copy=False).__finalize__(
#    5561         self, method="isin"
#    5562     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:477, in isin(comps, values)
#     472     raise TypeError(
#     473         "only list-like objects are allowed to be passed "
#     474         f"to isin(), you passed a `{type(comps).__name__}`"
#     475     )
#     476 if not is_list_like(values):
# --> 477     raise TypeError(
#     478         "only list-like objects are allowed to be passed "
#     479         f"to isin(), you passed a `{type(values).__name__}`"
#     480     )
#     482 if not isinstance(values, (ABCIndex, ABCSeries, ABCExtensionArray, np.ndarray)):
#     483     orig_values = list(values)
#
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a `int`
