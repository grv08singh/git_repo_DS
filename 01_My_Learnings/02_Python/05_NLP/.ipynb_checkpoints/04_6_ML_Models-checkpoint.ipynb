# %%
import cudf as cd
from cuml.model_selection import train_test_split
from cuml.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 import cudf as cd
#       2 from cuml.model_selection import train_test_split
# ----> 3 from cuml.metrics import accuracy_score, f1_score, confusion_matrix
#       4 from xgboost import XGBClassifier
#       5 from catboost import CatBoostClassifier
#
# ImportError: cannot import name 'f1_score' from 'cuml.metrics' (/home/dex/miniconda3/envs/rapids_env/lib/python3.11/site-packages/cuml/metrics/__init__.py)
