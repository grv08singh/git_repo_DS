# %%
import gensim
import os
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
from gensim.models import Word2Vec

# %%
story = []

# %%
for filename in os.listdir('datasets/GOT All Seasons Script/'):
    f = open(os.path.join('datasets/GOT All Seasons Script/',filename))
    corpus = f.read()
    raw_sentences = sent_tokenize(corpus)
    for sentence in raw_sentences:
        story.append(simple_preprocess(sentence))

# %%
model = Word2Vec(window=9, vector_size=100, min_count=2, workers=12)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (6569125, 8628190)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('stormborn', 0.7968781590461731),
#  ('targaryen', 0.7733771800994873),
#  ('queen', 0.7679513096809387),
#  ('princess', 0.7263389825820923),
#  ('unburnt', 0.718561589717865),
#  ('myrcella', 0.705046534538269),
#  ('elia', 0.6829633712768555),
#  ('viserys', 0.6816009879112244),
#  ('margaery', 0.6680824756622314),
#  ('joffrey', 0.6679210662841797)]

# %%
model.wv.doesnt_match(['jon','rikon','robb','arya','sansa','bran'])
# Out:
# 'jon'

# %%
model.wv.doesnt_match(['cersei', 'jaime', 'bronn', 'tyrion'])
# Out:
# 'bronn'

# %%
model.wv['king']
# Out:
# array([-0.10979381,  0.5187575 ,  1.7430866 ,  2.5042224 , -0.5714483 ,
#         2.2428398 ,  0.14167958, -0.15643369, -2.5142586 ,  0.03229459,
#        -0.63070107, -1.8895062 , -0.38829333,  0.8179502 , -1.7311279 ,
#        -2.3839028 ,  0.43629336,  2.4107103 ,  0.5011063 ,  0.61494166,
#         0.33037806, -0.91528296,  2.6090698 , -3.0550134 , -2.3290823 ,
#         1.7303164 , -0.7949475 , -1.3358867 ,  0.04027871,  1.4895426 ,
#        -3.147505  ,  0.7451422 , -0.53632843,  0.62958235,  0.5932495 ,
#        -5.020097  , -0.772207  , -1.2184997 ,  0.5139125 , -2.679794  ,
#        -1.4147097 ,  3.0744267 ,  1.3611351 , -0.0274866 , -0.96638244,
#        -3.1374962 ,  0.63198835, -2.555207  ,  2.342754  , -3.1517432 ,
#        -2.267808  , -2.2008681 , -1.3332801 , -2.2452853 ,  4.3827367 ,
#        -2.8172493 ,  1.3505994 , -0.5712788 ,  0.9284262 ,  1.1017383 ,
#         1.2310573 ,  1.4539642 ,  0.2875136 ,  0.12473973,  0.5363238 ,
# ...

# %%
model.wv.similarity('arya','sansa') #similarity score of arya and sansa
# Out:
# np.float32(0.8609096)

# %%
model.wv.get_normed_vectors()   #normalized vectors
# Out:
# array([[-0.03414708, -0.05121427,  0.06352855, ..., -0.00162444,
#         -0.03239566,  0.03058255],
#        [-0.18457758, -0.17232326, -0.06555907, ..., -0.14112298,
#          0.01370293,  0.19758746],
#        [ 0.06137727,  0.01483629, -0.09298629, ...,  0.0072376 ,
#          0.00396257, -0.05582195],
#        ...,
#        [-0.0400873 , -0.01441422,  0.03570931, ..., -0.08444307,
#          0.14057122, -0.01757898],
#        [-0.02973682,  0.02885266,  0.04545822, ..., -0.21005186,
#          0.16995835,  0.0570818 ],
#        [ 0.23252724,  0.02348647,  0.01674099, ...,  0.04012973,
#          0.04192187, -0.17892301]], dtype=float32)

# %%
model.wv.index_to_key           #all words in text form
# Out:
# ['the',
#  'and',
#  'to',
#  'of',
#  'he',
#  'his',
#  'was',
#  'you',
#  'her',
#  'in',
#  'it',
#  'had',
#  'that',
#  'she',
#  'as',
#  'with',
#  'him',
#  'not',
#  'but',
#  'for',
#  'they',
#  'is',
#  'at',
#  'on',
#  'said',
#  'my',
#  'have',
#  'be',
#  'lord',
#  'them',
#  'no',
#  'from',
#  'would',
#  'were',
#  'me',
#  'your',
#  'one',
#  'all',
#  'when',
#  'will',
#  'ser',
#  'if',
#  'so',
#  'their',
#  'we',
#  'could',
#  'are',
#  'man',
#  'there',
#  'this',
#  'up',
#  'been',
#  'what',
#  'did',
#  'by',
#  'king',
#  'do',
#  'men',
#  'back',
#  'out',
#  'more',
#  'or',
#  'who',
#  'down',
#  'well',
#  'than',
#  'only',
#  'like',
#  'jon',
#  'some',
#  'father',
#  'old',
#  'hand',
#  'even',
#  'too',
#  'tyrion',
#  'before',
#  'never',
#  'an',
#  'off',
#  'know',
#  'see',
#  'into',
#  'made',
#  'now',
#  'eyes',
#  'black',
#  'told',
#  'lady',
#  'thought',
#  'time',
#  'then',
#  'how',
#  'long',
#  'has',
#  'can',
# ...

# %%
model.wv

# %%
model.wv.similarity('jon','wall')
# Out:
# np.float32(0.43651277)
