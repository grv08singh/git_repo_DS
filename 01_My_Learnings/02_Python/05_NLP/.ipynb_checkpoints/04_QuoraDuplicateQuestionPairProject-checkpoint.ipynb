# %%
import cudf
import re
import string
import contractions
from textblob import TextBlob
import emoji
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/grv06sid/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = cudf.read_csv('datasets/Quora Questions Pair Dataset/train.csv')

# %%
df.sample(5)
# Out:
#             id    qid1    qid2  \
# 258755  258755  374390   83596
# 287170  287170   54800  147040
# 100976  100976  167362  167363
# 181745  181745  278349   12804
# 176953  176953  229812  272139
#
#                                                 question1  \
# 258755                  What is this boys haircut called?
# 287170  What will be the effect of India scrapping Rs....
# 100976  What are the basic and required things hr may ...
# 181745             Which is the richest man in the world?
# 176953  Why aren't we hearing about Donald Trump's all...
#
#                                                 question2 is_duplicate
# 258755                       What is this haircut called?            0
# 287170  What will be effect on stock exchange of India...            1
# 100976           Why can I find my fb friend Reshmi addy?            0
# 181745                            Who is the richest man?            1
# 176953  Is it true that Donald Trump raped a 13 year o...            1

# %%
def remove_html(text):
    pattern = re.compile(r'<.*?>')
    return pattern.sub('',text)

# %%
def remove_url(text):
    pattern = re.compile(r'http\S+|www\.\S+')
    return pattern.sub('',text)

# %%
def remove_punctuations(text):
    return text.translate(str.maketrans('','',string.punctuation))

# %%
def remove_multiple_space(text):
    pattern = re.compile(r'\s+')
    return pattern.sub(' ', text)

# %%
def correct_chat_words(text):
    chat_abbreviations = {
        "A3": "Anytime, Anywhere, Anyplace",
        "ADIH": "Another Day In Hell",
        "AFK": "Away From Keyboard",
        "AFAIK": "As Far As I Know",
        "ASAP": "As Soon As Possible",
        "ASL": "Age, Sex, Location",
        "ATK": "At The Keyboard",
        "ATM": "At The Moment",
        "BAE": "Before Anyone Else",
        "BAK": "Back At Keyboard",
        "BBL": "Be Back Later",
        "BBS": "Be Back Soon",
        "BFN": "Bye For Now",
        "B4N": "Bye For Now",
        "BRB": "Be Right Back",
        "BRUH": "Bro",
        "BRT": "Be Right There",
        "BSAAW": "Big Smile And A Wink",
        "BTW": "By The Way",
        "BWL": "Bursting With Laughter",
        "CSL": "Can’t Stop Laughing",
        "CU": "See You",
        "CUL8R": "See You Later",
        "CYA": "See You",
        "DM": "Direct Message",
        "FAQ": "Frequently Asked Questions",
        "FC": "Fingers Crossed",
        "FIMH": "Forever In My Heart",
        "FOMO": "Fear Of Missing Out",
        "FR": "For Real",
        "FWIW": "For What It's Worth",
        "FYP": "For You Page",
        "FYI": "For Your Information",
        "G9": "Genius",
        "GAL": "Get A Life",
        "GG": "Good Game",
        "GMTA": "Great Minds Think Alike",
        "GN": "Good Night",
        "GOAT": "Greatest Of All Time",
        "GR8": "Great!",
        "HBD": "Happy Birthday",
        "IC": "I See",
        "ICQ": "I Seek You",
        "IDC": "I Don’t Care",
        "IDK": "I Don't Know",
        "IFYP": "I Feel Your Pain",
        "ILU": "I Love You",
        "ILY": "I Love You",
        "IMHO": "In My Honest Opinion",
        "IMU": "I Miss You",
        "IMO": "In My Opinion",
        "IOW": "In Other Words",
        "IRL": "In Real Life",
        "IYKYK": "If You Know, You Know",
        "JK": "Just Kidding",
        "KISS": "Keep It Simple, Stupid",
        "L": "Loss",
        "L8R": "Later",
        "LDR": "Long Distance Relationship",
        "LMK": "Let Me Know",
        "LMAO": "Laughing My Ass Off",
        "LOL": "Laughing Out Loud",
        "LTNS": "Long Time No See",
        "M8": "Mate",
        "MFW": "My Face When",
        "MID": "Mediocre",
        "MRW": "My Reaction When",
        "MTE": "My Thoughts Exactly",
        "NVM": "Never Mind",
        "NRN": "No Reply Necessary",
        "NPC": "Non-Player Character",
        "OIC": "Oh I See",
        "OP": "Overpowered",
        "PITA": "Pain In The Ass",
        "POV": "Point Of View",
        "PRT": "Party",
        "PRW": "Parents Are Watching",
        "ROFL": "Rolling On The Floor Laughing",
        "ROFLOL": "Rolling On The Floor Laughing Out Loud",
        "ROTFLMAO": "Rolling On The Floor Laughing My Ass Off",
        "RN": "Right Now",
        "SK8": "Skate",
        "STATS": "Your Sex And Age",
        "SUS": "Suspicious",
        "TBH": "To Be Honest",
        "TFW": "That Feeling When",
        "THX": "Thank You",
        "TIME": "Tears In My Eyes",
        "TLDR": "Too Long, Didn’t Read",
        "TNTL": "Trying Not To Laugh",
        "TTFN": "Ta-Ta For Now!",
        "TTYL": "Talk To You Later",
        "U": "You",
        "U2": "You Too",
        "U4E": "Yours For Ever",
        "W": "Win",
        "W8": "Wait",
        "WB": "Welcome Back",
        "WTF": "What The Fuck",
        "WTG": "Way To Go!",
        "WUF": "Where Are You From?",
        "WYD": "What You Doing?",
        "WYWH": "Wish You Were Here",
        "ZZZ": "Sleeping, Bored, Tired"
    }
    new_text = []
    for word in text.split():
        word = word.replace(',','')
        word = word.replace('.','')
        word = word.upper()
        if word in chat_abbreviations.keys():
            new_text.append(chat_abbreviations[word])
        else:
            new_text.append(word)
    return " ".join(new_text).lower()

# %%
def expand_contractions(text):
    return contractions.fix(text)

# %%
def correct_spelling(text):
    txt_blob = TextBlob(text)
    return txt_blob.correct()

# %%
def remove_stopwords(text):
    stopwords = stopwords.words('english')
    filtered_words = [word for word in text.split() if word not in stopwords]
    return " ".join(filtered_words)

# %%
def handle_emojis(text):
    return emoji.demojize(text)

# %%
def remove_digits(text):
    pattern = re.compile(r'\d+')
    return pattern.sub('',text)

# %%
def lower_case(text):
    return text.lower()

# %%
def preprocess_text(text):
    text = remove_html(text)
    text = remove_url(text)
    text = remove_punctuations(text)
    text = remove_multiple_space(text)
    text = correct_chat_words(text)
    text = expand_contractions(text)
    text = correct_spelling(text)
    text = remove_stopwords(text)
    text = handle_emojis(text)
    text = remove_digits(text)
    text = lower_case(text)
    return text

# %%
df.info()
# Out:
# <class 'cudf.core.dataframe.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            404290 non-null  object
#  1   qid1          404290 non-null  object
#  2   qid2          404290 non-null  object
#  3   question1     404290 non-null  object
#  4   question2     404288 non-null  object
#  5   is_duplicate  404290 non-null  object
# dtypes: object(6)
# memory usage: 62.4+ MB

# %%
df['question1'] = df['question1'].apply(preprocess_text)
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/cudf/core/indexed_frame.py:3625, in IndexedFrame._apply(self, func, kernel_class, *args, **kwargs)
#    3624     kr = kernel_class(self, func, args)
# -> 3625     kernel, retty = kr.get_kernel()
#    3626 except Exception as e:
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/cudf/core/udf/udf_kernel_base.py:183, in ApplyKernelBase.get_kernel(self)
#     182 def get_kernel(self):
# --> 183     return self._compile_or_get_kernel()
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/cudf/core/udf/udf_kernel_base.py:200, in ApplyKernelBase._compile_or_get_kernel(self)
#     198     return kernel, masked_or_scalar
# --> 200 kernel, scalar_return_type = self.compile_kernel()
#     202 np_return_type = (
#     203     numpy_support.as_dtype(scalar_return_type)
#     204     if scalar_return_type.is_internal
#     205     else scalar_return_type.np_dtype
#     206 )
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/cudf/core/udf/udf_kernel_base.py:149, in ApplyKernelBase.compile_kernel(self)
#     148 with capture_nrt_usage:
# --> 149     return_type = self._get_udf_return_type()
#     151 self.sig = self._construct_signature(return_type)
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/cudf/core/udf/udf_kernel_base.py:116, in ApplyKernelBase._get_udf_return_type(self)
#     115 with _CUDFNumbaConfig():
# --> 116     _, output_type = compile_udf(self.func, compile_sig)
#     117 if isinstance(output_type, MaskedType):
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/cudf/core/udf/utils.py:208, in compile_udf(udf, type_signature)
#     206 # We haven't compiled a function like this before, so need to fall back to
#     207 # compilation with Numba
# --> 208 ptx_code, return_type = cuda.compile_ptx_for_current_device(
#     209     udf, type_signature, device=True
#     210 )
#     211 if not isinstance(return_type, MaskedType):
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/compiler.py:1330, in compile_ptx_for_current_device(pyfunc, sig, debug, lineinfo, device, fastmath, opt, abi, abi_info, forceinline, launch_bounds)
#    1329 cc = get_current_device().compute_capability
# -> 1330 return compile_ptx(
#    1331     pyfunc,
#    1332     sig,
#    1333     debug=debug,
#    1334     lineinfo=lineinfo,
#    1335     device=device,
#    1336     fastmath=fastmath,
#    1337     cc=cc,
#    1338     opt=opt,
#    1339     abi=abi,
#    1340     abi_info=abi_info,
#    1341     forceinline=forceinline,
#    1342     launch_bounds=launch_bounds,
#    1343 )
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/compiler.py:1297, in compile_ptx(pyfunc, sig, debug, lineinfo, device, fastmath, cc, opt, abi, abi_info, forceinline, launch_bounds)
#    1293 """Compile a Python function to PTX for a given signature. See
#    1294 :func:`compile`. The defaults for this function are to compile a kernel
#    1295 with the Numba ABI, rather than :func:`compile`'s default of compiling a
#    1296 device function with the C ABI."""
# -> 1297 return compile(
#    1298     pyfunc,
#    1299     sig,
#    1300     debug=debug,
#    1301     lineinfo=lineinfo,
#    1302     device=device,
#    1303     fastmath=fastmath,
#    1304     cc=cc,
#    1305     opt=opt,
#    1306     abi=abi,
#    1307     abi_info=abi_info,
#    1308     output="ptx",
#    1309     forceinline=forceinline,
#    1310     launch_bounds=launch_bounds,
#    1311 )
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/compiler_lock.py:74, in _DualCompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      73 with self:
# ---> 74     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/compiler.py:1214, in compile(pyfunc, sig, debug, lineinfo, device, fastmath, cc, opt, abi, abi_info, output, forceinline, launch_bounds)
#    1213 lto = output == "ltoir"
# -> 1214 lib, resty = _compile_pyfunc_with_fixup(
#    1215     pyfunc,
#    1216     sig,
#    1217     debug=debug,
#    1218     lineinfo=lineinfo,
#    1219     device=device,
#    1220     fastmath=fastmath,
#    1221     cc=cc,
#    1222     opt=opt,
#    1223     abi=abi,
#    1224     abi_info=abi_info,
#    1225     forceinline=forceinline,
#    1226     launch_bounds=launch_bounds,
#    1227     lto=lto,
#    1228 )
#    1230 if lto:
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/compiler.py:1106, in _compile_pyfunc_with_fixup(pyfunc, sig, debug, lineinfo, device, fastmath, cc, opt, abi, abi_info, forceinline, launch_bounds, lto)
#    1104 cc = _default_cc(cc)
# -> 1106 cres = compile_cuda(
#    1107     pyfunc,
#    1108     return_type,
#    1109     args,
#    1110     debug=debug,
#    1111     lineinfo=lineinfo,
#    1112     fastmath=fastmath,
#    1113     nvvm_options=nvvm_options,
#    1114     cc=cc,
#    1115     forceinline=forceinline,
#    1116     abi=abi,
#    1117     abi_info=abi_info,
#    1118 )
#    1119 resty = cres.signature.return_type
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/compiler_lock.py:74, in _DualCompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      73 with self:
# ---> 74     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/compiler.py:789, in compile_cuda(pyfunc, return_type, args, debug, lineinfo, forceinline, inline, fastmath, nvvm_options, cc, max_registers, lto, abi, abi_info)
#     788 with utils.numba_target_override():
# --> 789     cres = compile_extra(
#     790         typingctx=typingctx,
#     791         targetctx=targetctx,
#     792         func=pyfunc,
#     793         args=args,
#     794         return_type=return_type,
#     795         flags=flags,
#     796         locals={},
#     797         pipeline_class=CUDACompiler,
#     798         call_conv=call_conv,
#     799         abi_info=abi_info,
#     800     )
#     802 library = cres.library
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/compiler.py:599, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class, call_conv, abi_info)
#     588 pipeline = pipeline_class(
#     589     typingctx,
#     590     targetctx,
#    (...)    597     abi_info,
#     598 )
# --> 599 return pipeline.compile_extra(func)
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/compiler.py:146, in CompilerBase.compile_extra(self, func)
#     145 self.state.lifted_from = None
# --> 146 return self._compile_bytecode()
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/compiler.py:214, in CompilerBase._compile_bytecode(self)
#     213 assert self.state.func_ir is None
# --> 214 return self._compile_core()
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/compiler.py:193, in CompilerBase._compile_core(self)
#     192         if is_final_pipeline:
# --> 193             raise e
#     194 else:
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/compiler.py:182, in CompilerBase._compile_core(self)
#     181 try:
# --> 182     pm.run(self.state)
#     183     if self.state.cr is not None:
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/compiler_machinery.py:398, in PassManager.run(self, state)
#     397 patched_exception = self._patch_error(msg, e)
# --> 398 raise patched_exception
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/compiler_machinery.py:385, in PassManager.run(self, state)
#     384 if isinstance(pass_inst, CompilerPass):
# --> 385     self._runPass(idx, pass_inst, state)
#     386 else:
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/compiler_lock.py:74, in _DualCompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      73 with self:
# ---> 74     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/compiler_machinery.py:337, in PassManager._runPass(self, index, pss, internal_state)
#     336 with SimpleTimer() as pass_time:
# --> 337     mutated |= check(pss.run_pass, internal_state)
#     338 with SimpleTimer() as finalize_time:
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/compiler_machinery.py:291, in PassManager._runPass.<locals>.check(func, compiler_state)
#     290 def check(func, compiler_state):
# --> 291     mangled = func(compiler_state)
#     292     if mangled not in (True, False):
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/typed_passes.py:141, in BaseTypeInference.run_pass(self, state)
#     136 with fallback_context(
#     137     state,
#     138     'Function "%s" failed type inference' % (state.func_id.func_name,),
#     139 ):
#     140     # Type inference
# --> 141     typemap, return_type, calltypes, errs = type_inference_stage(
#     142         state.typingctx,
#     143         state.targetctx,
#     144         state.func_ir,
#     145         state.args,
#     146         state.return_type,
#     147         state.locals,
#     148         raise_errors=self._raise_errors,
#     149     )
#     150     state.typemap = typemap
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/typed_passes.py:118, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#     116     infer.seed_type(k, v)
# --> 118 infer.build_constraint()
#     119 # return errors in case of partial typing
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/typeinfer.py:1108, in TypeInferer.build_constraint(self)
#    1107 for inst in blk.body:
# -> 1108     self.constrain_statement(inst)
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/typeinfer.py:1501, in TypeInferer.constrain_statement(self, inst)
#    1500 if isinstance(inst, ir.assign_types):
# -> 1501     self.typeof_assign(inst)
#    1502 elif isinstance(inst, ir.setitem_types):
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/typeinfer.py:1597, in TypeInferer.typeof_assign(self, inst)
#    1594 elif isinstance(value, ir.global_types) or isinstance(
#    1595     value, ir.freevar_types
#    1596 ):
# -> 1597     self.typeof_global(inst, inst.target, value)
#    1598 elif isinstance(value, ir.arg_types):
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/typeinfer.py:1699, in TypeInferer.typeof_global(self, inst, target, gvar)
#    1698 try:
# -> 1699     typ = self.resolve_value_type(inst, gvar.value)
#    1700 except TypingError as e:
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/numba_cuda/numba/cuda/core/typeinfer.py:1620, in TypeInferer.resolve_value_type(self, inst, val)
#    1619     msg = str(e)
# -> 1620 raise TypingError(msg, loc=inst.loc)
#
# TypingError: Failed in cuda mode pipeline (step: nopython frontend)
# Untyped global name 'remove_html': Cannot determine Numba type of <class 'function'>
#
# File "../../../../../../../tmp/ipykernel_905/1045317060.py", line 2:
# <source missing, REPL/exec in use?>
#
# During: Pass nopython_type_inference
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df['question1'] = df['question1'].apply(preprocess_text)
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/cudf/core/series.py:2646, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    2643     result.name = self.name
#    2644     return result
# -> 2646 result = self._apply(func, SeriesApplyKernel, *args, **kwargs)
#    2647 result.name = self.name
#    2648 return result
#
# File ~/miniconda3/envs/rapids-26.06/lib/python3.12/site-packages/cudf/core/indexed_frame.py:3627, in IndexedFrame._apply(self, func, kernel_class, *args, **kwargs)
#    3625     kernel, retty = kr.get_kernel()
#    3626 except Exception as e:
# -> 3627     raise ValueError(
#    3628         "user defined function compilation failed."
#    3629     ) from e
#    3631 # Mask and data column preallocated
#    3632 ans_col = _return_arr_from_dtype(retty, len(self))
#
# ValueError: user defined function compilation failed.
