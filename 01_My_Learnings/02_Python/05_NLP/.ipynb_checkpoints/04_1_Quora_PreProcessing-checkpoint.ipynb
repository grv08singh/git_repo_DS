# %%
#1st time use
#%load_ext cudf.pandas
#subsequent use
# %reload_ext cudf.pandas

import yaml
import pandas as pd
import numba
import re
import string
import contractions
from textblob import TextBlob
import emoji
import tqdm
from tqdm import tqdm
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from symspellpy import SymSpell, Verbosity
import pkg_resources
# Out:
# [nltk_data] Downloading package stopwords to /home/dex/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /tmp/ipykernel_655/3189034434.py:20: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
#df = cudf.read_csv('datasets/Quora Questions Pair Dataset/train.csv')
df = pd.read_csv('datasets/Quora Questions Pair Dataset/train.csv')

# %%
# remove unnecessary columns
df.drop(columns=['id','qid1','qid2'], inplace=True)

# %%
df.sample(3)
# Out:
#                                                 question1  \
# 381211   Do microwave ovens cause cancer? Why or why not?
# 38499   As owner of a small biz, how do I address two ...
# 178908  What do interstitial markings represent on a c...
#
#                                                 question2 is_duplicate
# 381211                    Can microwave use cause cancer?            0
# 38499   I sent a whistle from CA to OH. Supposedly USP...            0
# 178908  I have cleared group 1 IPCC but haven't done I...            0

# %%
#lower case
df['question1'] = df['question1'].str.lower()
df['question2'] = df['question2'].str.lower()

# %%
# remove html tags
df['question1'] = df['question1'].str.replace(r'<.*?>','',regex=True)
df['question2'] = df['question2'].str.replace(r'<.*?>','',regex=True)

# %%
# remove web links
df['question1'] = df['question1'].str.replace(r'http\S+|www\.\S+','',regex=True)
df['question2'] = df['question2'].str.replace(r'http\S+|www\.\S+','',regex=True)

# %%
# expand contractions: you're --> you are, i'm --> i am
question1 = df['question1']
question2 = df['question2']
for contraction, expanded in tqdm(contractions.contractions_dict.items(), desc="Expanding Contractions..."):
    question1 = question1.str.replace(rf'\b{re.escape(contraction.lower())}\b', expanded.lower(), regex=True)
    question2 = question2.str.replace(rf'\b{re.escape(contraction.lower())}\b', expanded.lower(), regex=True)
df['question1'] = question1
df['question2'] = question2
# Out:
# Expanding Contractions...: 100%|████████████████████████████████████████████████████| 344/344 [00:13<00:00, 24.93it/s]

# %%
# expand chatwords
with open("datasets/chat_words.yaml", "r", encoding="utf-8") as f:
    chat_words = yaml.safe_load(f)

question1 = df['question1']
question2 = df['question2']
for chat_word, full_word in tqdm(chat_words.items(), desc="Correcting Questions"):
    question1 = question1.str.replace(rf'\b{re.escape(chat_word.lower())}\b', full_word, regex=True)
    question2 = question2.str.replace(rf'\b{re.escape(chat_word.lower())}\b', full_word, regex=True)
df['question1'] = question1
df['question2'] = question2
# Out:
# Correcting Questions: 100%|█████████████████████████████████████████████████████████| 106/106 [00:04<00:00, 25.28it/s]

# %%
sym_replace = {
    '%': ' percent ',
    '$': ' dollar ',
    '₹': ' rupee ',
    '€': ' euro ',
    '@': ' at '
}
q1 = df['question1']
q2 = df['question2']
for sym, replacement in tqdm(sym_replace.items(), desc="replacing symbols..."):
    q1 = q1.str.replace(rf'\b{re.escape(sym)}\b', replacement, regex=True)
    q2 = q2.str.replace(rf'\b{re.escape(sym)}\b', replacement, regex=True)
df['question1'] = q1
df['question2'] = q2
# Out:
# replacing symbols...: 100%|█████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 23.69it/s]

# %%
# remove stopwords
stop_words = stopwords.words('english')
stopword_removed_q1 = df['question1']
stopword_removed_q2 = df['question2']
for stop_word in tqdm(stop_words, desc='Removing Stop Words'):
    stopword_removed_q1 = stopword_removed_q1.str.replace(rf'\b{re.escape(stop_word)}\b', '', regex=True)
    stopword_removed_q2 = stopword_removed_q2.str.replace(rf'\b{re.escape(stop_word)}\b', '', regex=True)
df['question1'] = stopword_removed_q1
df['question2'] = stopword_removed_q2
# Out:
# Removing Stop Words: 100%|██████████████████████████████████████████████████████████| 198/198 [00:07<00:00, 28.12it/s]

# %%
# remove emojis
emoji_pattern = r'[\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-\U0001F6FF\U0001F1E0-\U0001F1FF\U00002702-\U000027B0\U000024C2-\U0001F251]+'
df['question1'] = df['question1'].str.replace(emoji_pattern, '', regex=True)
df['question2'] = df['question2'].str.replace(emoji_pattern, '', regex=True)

# %%
# remove punctuations
df['question1'] = df['question1'].str.replace(r'''[!"#$%&\'()*+,\-./:;<=>?@\[\\\]^_`{|}~]''','',regex=True)
df['question2'] = df['question2'].str.replace(r'''[!"#$%&\'()*+,\-./:;<=>?@\[\\\]^_`{|}~]''','',regex=True)

# %%
# correct spellings using symspellpy
tokens_series1 = df['question1'].str.findall(r'\b[a-z]+\b')
tokens_series2 = df['question2'].str.findall(r'\b[a-z]+\b')
tokens_series = pd.concat([tokens_series1,tokens_series2], axis=0, ignore_index=True) #tokenization per row

all_words = tokens_series.explode().dropna()   # all unique words
unique_words = all_words.unique()#.to_pandas()  # CPU transfer

sym = SymSpell(max_dictionary_edit_distance=2, prefix_length=7)
dict_path = pkg_resources.resource_filename(
    "symspellpy", "frequency_dictionary_en_82_765.txt"
)
sym.load_dictionary(dict_path, term_index=0, count_index=1)

# creating spell correction map (dictionary) for current data
correction_map = {}
for word in unique_words:
    if word not in sym.words:  # word not in dictionary → likely misspelled
        suggestions = sym.lookup(word, Verbosity.CLOSEST, max_edit_distance=2)
        if suggestions:
            correction_map[word] = suggestions[0].term

# correcting the spellings
corrected_q1 = df['question1']
corrected_q2 = df['question2']
for wrong, right in tqdm(correction_map.items(), desc="Correcting Questions"):
    corrected_q1 = corrected_q1.str.replace(rf'\b{re.escape(wrong)}\b', right, regex=True)
    corrected_q2 = corrected_q2.str.replace(rf'\b{re.escape(wrong)}\b', right, regex=True)
df['question1'] = corrected_q1
df['question2'] = corrected_q2
# Out:
# Correcting Questions:   5%|██▋                                                   | 1555/31936 [00:41<13:39, 37.06it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 28
#      24 corrected_q1 = df['question1']
#      25 corrected_q2 = df['question2']
#      26 for wrong, right in tqdm(correction_map.items(), desc="Correcting Questions"):
#      27     corrected_q1 = corrected_q1.str.replace(rf'\b{re.escape(wrong)}\b', right, regex=True)
# ---> 28     corrected_q2 = corrected_q2.str.replace(rf'\b{re.escape(wrong)}\b', right, regex=True)
#      29 df['question1'] = corrected_q1
#      30 df['question2'] = corrected_q2
#
# File ~/miniconda3/envs/rapids_env/lib/python3.11/site-packages/cudf/pandas/fast_slow_proxy.py:885, in _CallableProxyMixin.__call__(self, *args, **kwargs)
#     884 def __call__(self, *args, **kwargs) -> Any:
# --> 885     result, _ = _fast_slow_function_call(
#     886         # We cannot directly call self here because we need it to be
#     887         # converted into either the fast or slow object (by
#     888         # _fast_slow_function_call) to avoid infinite recursion.
#     889         # TODO: When Python 3.11 is the minimum supported Python version
#     890         # this can use operator.call
#     891         call_operator,
#     892         self.get_transfer_blocking(),  # type: ignore[attr-defined]
#     893         self,
#     894         args,
#     895         kwargs,
#     896     )
#     897     return result
#
# File ~/miniconda3/envs/rapids_env/lib/python3.11/site-packages/cudf/pandas/fast_slow_proxy.py:1193, in _fast_slow_function_call(func, transfer_block, *args, **kwargs)
#    1187 with nvtx.annotate(
#    1188     "EXECUTE_FAST",
#    1189     color=_CUDF_PANDAS_NVTX_COLORS["EXECUTE_FAST"],
#    1190     domain="cudf_pandas",
#    1191 ):
#    1192     fast_args, fast_kwargs = _fast_arg(args), _fast_arg(kwargs)
# -> 1193     result = func(*fast_args, **fast_kwargs)
#    1194     if result is NotImplemented:
#    1195         # try slow path
#    1196         raise Exception()
#
# File ~/miniconda3/envs/rapids_env/lib/python3.11/site-packages/cudf/pandas/fast_slow_proxy.py:30, in call_operator(fn, args, kwargs)
#      29 def call_operator(fn, args, kwargs):
# ---> 30     return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/rapids_env/lib/python3.11/site-packages/cudf/core/accessors/string.py:1055, in StringMethods.replace(self, pat, repl, n, case, flags, regex)
#    1053 # Pandas forces non-regex replace when pat is a single-character
#    1054 if regex is True and len(pat) > 0:
# -> 1055     result = self._column.replace_re(
#    1056         pat,  # type: ignore[arg-type]
#    1057         repl,
#    1058         n,
#    1059     )
#    1060 else:
#    1061     result = self._column.replace_str(
#    1062         pat,  # type: ignore[arg-type]
#    1063         repl,
#    1064         n,
#    1065     )
#
# File ~/miniconda3/envs/rapids_env/lib/python3.11/site-packages/cudf/core/column/string.py:1476, in StringColumn.replace_re(self, pattern, replacement, max_replace_count)
#    1469     plc_column = plc.strings.replace_re.replace_re(
#    1470         self.plc_column,
#    1471         pattern,
#    1472         replacement.plc_column,
#    1473         max_replace_count,
#    1474     )
#    1475 elif isinstance(pattern, str) and isinstance(replacement, str):
# -> 1476     plc_column = plc.strings.replace_re.replace_re(
#    1477         self.plc_column,
#    1478         plc.strings.regex_program.RegexProgram.create(
#    1479             pattern,
#    1480             plc.strings.regex_flags.RegexFlags.DEFAULT,
#    1481         ),
#    1482         plc.Scalar.from_py(
#    1483             replacement, dtype=plc.DataType(plc.TypeId.STRING)
#    1484         ),
#    1485         max_replace_count,
#    1486     )
#    1487 else:
#    1488     raise ValueError("Invalid pattern and replacement types")
#
# File pylibcudf/strings/replace_re.pyx:26
# ---> 26 # SPDX-FileCopyrightText: Copyright (c) 2024-2026, NVIDIA CORPORATION.
#
# File pylibcudf/strings/replace_re.pyx:89
# ---> 89 # SPDX-FileCopyrightText: Copyright (c) 2024-2026, NVIDIA CORPORATION.
#
# File pylibcudf/column.pyx:689
# --> 689     @staticmethod
#     690     cdef Column from_libcudf(
#     691         unique_ptr[column] libcudf_col,
#     692         object stream,
#
# File rmm/pylibrmm/device_buffer.pyx:213
# --> 213     @staticmethod
#     214     cdef DeviceBuffer c_from_unique_ptr(
#     215         unique_ptr[device_buffer] ptr,
#     216         Stream stream=DEFAULT_STREAM,
#
# File rmm/pylibrmm/device_buffer.pyx:84
# ---> 84     def __cinit__(self, *,
#      85                   uintptr_t ptr=0,
#      86                   size_t size=0,
#      87                   Stream stream=DEFAULT_STREAM,
#
# File rmm/pylibrmm/memory_resource/_memory_resource.pyx:1160
# -> 1160     def __init__(
#    1161         self,
#    1162         DeviceMemoryResource upstream_mr
#    1163     ):
#
# File ~/miniconda3/envs/rapids_env/lib/python3.11/site-packages/rmm/_cuda/gpu.py:57, in getDevice()
#      53         raise CUDARuntimeError(status)
#      54     return version
# ---> 57 def getDevice() -> int:
#      58     """
#      59     Get the current CUDA device
#      60     """
#      61     status, device = runtime.cudaGetDevice()
#
# KeyboardInterrupt:

# %%
# remove extra white spaces
df['question1'] = df['question1'].str.strip().str.replace(r'\s+',' ',regex=True)
df['question2'] = df['question2'].str.strip().str.replace(r'\s+',' ',regex=True)

# %%
df.isnull().sum()
# Out:
# question1       0
# question2       2
# is_duplicate    0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# question1       0
# question2       0
# is_duplicate    0
# dtype: int64

# %%
df['len1'] = df['question1'].str.split().list.len()
df['len2'] = df['question2'].str.split().list.len()
df.shape
# Out:
# (404288, 5)

# %%
df = df[(df['len1'] > 2) & (df['len2'] > 2)]
df.shape
# Out:
# (403961, 5)

# %%
df
# Out:
#                                                 question1  \
# 0       what is the step by step guide to invest in sh...
# 1          what is the story of kohinoor kohinoor diamond
# 2       how can i increase the speed of my internet co...
# 3        why am i mentally very lonely how can i solve it
# 4       which one dissolve in water quikly sugar salt ...
# ...                                                   ...
# 404285  how many keywords are there in the racket prog...
# 404286           do you believe there is life after death
# 404287                                   what is one coin
# 404288  what is the approx annual cost of living while...
# 404289               what is like to have sex with cousin
#
#                                                 question2 is_duplicate  len1  \
# 0       what is the step by step guide to invest in sh...            0    14
# 1       what would happen if the indian government sto...            0     8
# 2       how can internet speed be increased by hacking...            0    14
# 3          find the remainder when mathmath is divided by            0    11
# 4                  which fish would survive in salt water            0    13
# ...                                                   ...          ...   ...
# 404285  how many keywords are there in perl programmin...            0    14
# 404286          is it true that there is life after death            1     8
# 404287                                  what is this coin            0     4
# 404288  i am having little hairfall problem but i want...            0    17
# 404289       what is it like to have sex with your cousin            0     8
#
#         len2
# 0         12
# 1         13
# 2         10
# 3          8
# 4          7
# ...      ...
# 404285    13
# 404286     9
# 404287     4
# 404288    25
# 404289    10
#
# [403961 rows x 5 columns]

# %%
df = df[['question1', 'question2', 'is_duplicate']]

# %%
df.to_pandas().to_csv('datasets/Quora Questions Pair Dataset/train_preprocessed.csv', index=False)
